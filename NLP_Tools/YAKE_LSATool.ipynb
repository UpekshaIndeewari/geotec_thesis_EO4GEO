# %%
#install PyPDF2 library
! pip install PyPDF2
#install nltk library
! pip install nltk==3.5
#install matplotlib library
! pip install numpy matplotlib
#install spell checker library
! pip install pyenchant
#install jason library
! pip install json
#install YAKE library for automatic key phrase extraction
! pip install yake
#install library to exrace the header and footer from the text
! pip install PyMuPDF
# Out:
# Requirement already satisfied: PyPDF2 in c:\users\prasa\anaconda3\lib\site-packages (3.0.1)
# Requirement already satisfied: nltk==3.5 in c:\users\prasa\anaconda3\lib\site-packages (3.5)
# Requirement already satisfied: click in c:\users\prasa\anaconda3\lib\site-packages (from nltk==3.5) (8.0.4)
# Requirement already satisfied: joblib in c:\users\prasa\anaconda3\lib\site-packages (from nltk==3.5) (1.2.0)
# Requirement already satisfied: regex in c:\users\prasa\anaconda3\lib\site-packages (from nltk==3.5) (2022.7.9)
# Requirement already satisfied: tqdm in c:\users\prasa\anaconda3\lib\site-packages (from nltk==3.5) (4.65.0)
# Requirement already satisfied: colorama in c:\users\prasa\appdata\roaming\python\python311\site-packages (from click->nltk==3.5) (0.4.6)
# Requirement already satisfied: numpy in c:\users\prasa\anaconda3\lib\site-packages (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\prasa\anaconda3\lib\site-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prasa\anaconda3\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\prasa\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prasa\anaconda3\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\prasa\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\prasa\appdata\roaming\python\python311\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\prasa\anaconda3\lib\site-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\prasa\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\prasa\appdata\roaming\python\python311\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\prasa\appdata\roaming\python\python311\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: pyenchant in c:\users\prasa\anaconda3\lib\site-packages (3.2.2)
# ERROR: Could not find a version that satisfies the requirement json (from versions: none)
# ERROR: No matching distribution found for json
# Requirement already satisfied: yake in c:\users\prasa\anaconda3\lib\site-packages (0.4.8)
# Requirement already satisfied: tabulate in c:\users\prasa\anaconda3\lib\site-packages (from yake) (0.8.10)
# Requirement already satisfied: click>=6.0 in c:\users\prasa\anaconda3\lib\site-packages (from yake) (8.0.4)
# Requirement already satisfied: numpy in c:\users\prasa\anaconda3\lib\site-packages (from yake) (1.24.3)
# Requirement already satisfied: segtok in c:\users\prasa\anaconda3\lib\site-packages (from yake) (1.5.11)
# Requirement already satisfied: networkx in c:\users\prasa\anaconda3\lib\site-packages (from yake) (3.1)
# Requirement already satisfied: jellyfish in c:\users\prasa\anaconda3\lib\site-packages (from yake) (0.9.0)
# Requirement already satisfied: colorama in c:\users\prasa\appdata\roaming\python\python311\site-packages (from click>=6.0->yake) (0.4.6)
# Requirement already satisfied: regex in c:\users\prasa\anaconda3\lib\site-packages (from segtok->yake) (2022.7.9)
# Requirement already satisfied: PyMuPDF in c:\users\prasa\anaconda3\lib\site-packages (1.23.8)
# Requirement already satisfied: PyMuPDFb==1.23.7 in c:\users\prasa\anaconda3\lib\site-packages (from PyMuPDF) (1.23.7)

# %%
# IMPORT REQUIRD LIBRARIES 
import nltk
import fitz 
import re
import pandas as pd
import matplotlib.pyplot as plt
import enchant
import json
import string
import yake
import numpy as np
from PyPDF2 import PdfReader
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords
from nltk.corpus import words
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import TruncatedSVD
from sklearn.preprocessing import Normalizer
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('words')

#\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\\
# This is the function for automate the annotation PDF resources with EO4GEOBOK concepts

# This function (YAKE_LSA) contains main 05 functions
      # a. Text cleaning function --> Text_Cleaner()
      # b. Automatic extracion of list of BOK concept  --> EO4GEO()
      # c. Automatic Key phrases extraction from text given by PDF --> YAKE_Extractor()
      # d. Similarity measurement between extracted key phrases and EO4GEO concepts --> LSA_Similarity
      # e. Download output results as a JSON format --> Create_Json()
      
def YAKE_LSA(pdf):
      
# 01. FUNCTION FOR TEXT CLEANING  
   
   global corrected_words
   corrected_words = []

   def Text_Cleaner():
   # 1. Function to show metadata of the PDF
      def metaData(pdf):
         reader = PdfReader(pdf)
         meta = reader.metadata
         print("Meta data of the PDF")
         print("Total number of pages in the PDF file is: ", len(reader.pages))
         print("Author name:", meta.author)
         print("Creator name:", meta.creator)
         print("Producer name:", meta.producer)
      metaData(pdf)
   #-----------------------------------------------------------------------------------
   # 2. Remove footers from the text
      def remove_Singlelines(text):
         pattern = r'AGILE: GIScience Series.*?https://doi\.org/[^\s]+'
         matches = re.findall(pattern, text)
         removed_text = ""
         for match in matches:
            removed_text += match + "\n"
            text = text.replace(match, '')
         return removed_text, text.strip()
      
      global http_sections
      http_sections = ""
      
   # 3. Remove headers from the text
      def remove_Agilelicense(text):
         pattern = r'AGILE: GIScience Series.*?This work is distributed under the Creative Commons Attribution 4.0 License'
         match = re.search(pattern, text, flags=re.DOTALL)
         removed_text = ""
         global http_sections
         if match:
            removed_text = match.group(0)
            text = text.replace(removed_text, '')
            http_pattern = re.compile(r'https?://doi\.org/[^\s]+')
            http_matches = re.findall(http_pattern, removed_text)
            http_sections += " ".join(http_matches)
         return removed_text, text.strip(),http_sections

      def extract_agile_info(pdf_path):
         doc = fitz.open(pdf_path)
         agile_info = ""
         inagile_section = False

         for page_number in range(doc.page_count):
            page = doc[page_number]
            text = page.get_text("text")
            
            if "AGILE: GIScience Series" in text:
               inagile_section = True
               agile_info += text

            elif inagile_section and "© Author(s)" in text:
               agile_info += text
               inagile_section = False
               break
            
            elif inagile_section:
               agile_info += text

         doc.close()
         return agile_info.strip()

      pdf_path = pdf
      extracted_info = extract_agile_info(pdf_path)
      remagile_part, cleanedtext_agile,http_sections = remove_Agilelicense(extracted_info)
      remsingle_lines, cleanedtext_all = remove_Singlelines(cleanedtext_agile)
      print("\nRemoved Header:")
      print(remagile_part)
      print("\nRemoved Footers:")
      print(remsingle_lines)
      print("\nDOI of the paper:")
      print(http_sections)
   #----------------------------------------------------------------------------------------
   # 4. Remove hyphens within words
      def remove_Hypens(text):
         stringwithout_hyp = text.replace('-', ' ')
         return stringwithout_hyp
      withouthypen = remove_Hypens(cleanedtext_all)
   #--------------------------------------------------------------------------------------
   # 5.Tokenization - split the entire paragraph into words (tokens)
      def token_Words(text):
         list_words = word_tokenize(text)
         return list_words
      split_words = token_Words(withouthypen)
   #---------------------------------------------------------------------------------------
   # 6.Filterd the required portion
      def split_Portion(para):
         index1 = para.index('Abstract')
         index2 = para.index('References')
         filter_potion=para[index1+1:index2]
         return filter_potion
      filter = split_Portion(split_words)
   #-----------------------------------------------------------------------------------------
   # 7.Extract the title ofthe document
      global title
      def title_Ex(word_list):
         index3 = word_list.index('Abstract')
         title = word_list[0:index3]
         separator = ' ' 
         result = separator.join(title) 
         return result
      title = title_Ex(split_words)
   #---------------------------------------------------------------------------------------
   # 8. Convert words in to lowercases
      def lowercase_Words(list):
         lowercase_remain =[]
         for i in list:
            x = i.lower()
            lowercase_remain.append(x)
         return lowercase_remain
      lower_words = lowercase_Words(filter)
   #------------------------------------------------------------------------------------------
   # 9. Remove cases.Remove some words and letters which are not in English language
      def remove_Case(text_remain):
         cleaned_texts =[]
         for text in text_remain:
            text = text.casefold()
            cleaned_texts.append(text)
         return cleaned_texts
      Rem_cases = remove_Case(lower_words)
   #----------------------------------------------------------------------------------------
   # 10. Remove Stop words in English language
      def remove_Stopword(cleaned_texts):
         stop_words = stopwords.words('english')
         stopword_list = []
         nostopword_list = []
         for word in cleaned_texts:
            if word in stop_words:
               stopword_list.append(word)
            elif word not in stop_words:
               nostopword_list.append(word)
         return nostopword_list
      Rem_stopwords = remove_Stopword(Rem_cases) 
   #-----------------------------------------------------------------------------------------
   # 11.Remove unicode symbols from the text
      def remove_Unicode(nostop_word):
         no_unicode = []
         for word in nostop_word:
            cleaned_word = re.sub(r'[^\x00-\x7F]+', '', word)
            no_unicode.append(cleaned_word)
         return no_unicode
      Rem_unicodes = remove_Unicode(Rem_stopwords)
   #-------------------------------------------------------------------------------------------
   # 12. Remove numbers and digits
      def remove_Numbers(nounicode_list):
         no_number_list = []
         number_list = []
         for token in nounicode_list:
            if token.isdigit():
               number_list.append(token)  
            elif token.count('.') == 1 and token.replace('.', '').isdigit():
               number_list.append(token) 
            else:
               no_number_list.append(token) 
         return no_number_list
      Rem_numbers = remove_Numbers(Rem_unicodes) 
   #-------------------------------------------------------------------------------------------
   # 13. Remove special words with having mix of string, numbers, punctuations and other symbols
      def remove_Special(nospecial_list):
         no_sp_words = []
         numstring_list = []
      # Regular expression pattern to match any string containing numeric characters or hyphens
         pattern = r'^(?=.*\d)(?=.*[A-Za-z])|(?=.*[A-Za-z])(?=.*[\W_])|(?=.*\d)(?=.*[\W_])'
         for text in nospecial_list:
            if not re.match(pattern, text):
               no_sp_words.append(text)
            elif re.match(pattern, text):
               numstring_list.append(text) 
         return no_sp_words
      Rem_special = remove_Special(Rem_numbers)
   #---------------------------------------------------------------------------------------
   # 14. remove URL, @
      def remove_Repeat(nosp_words):
         list1 = []
         list2 = []
         text1 = r"(@\[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?"
         for i in nosp_words:
            if not re.match(text1, i):
               list1.append(i)
            elif re.match(text1, i):
               list2.append(i)
         return list1
      Rem_url = remove_Repeat(Rem_special)
   #---------------------------------------------------------------------------------------
   # 15.Remove punctuations from the list
      def remove_Punc(cleaned_words):
         punctuation_marks=[]
         withoutpunct_marks=[]
         for token in cleaned_words:
            if token in ("!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"):
               punctuation_marks.append(token)
            elif token not in ("!\"#$%&'()*+,-./:;<=>?@[\]^_`{|}~"):
               withoutpunct_marks.append(token)
         return withoutpunct_marks
      Rem_punc = remove_Punc(Rem_url)
   #----------------------------------------------------------------------------------------
   # 16. Remove word repetition
      def word_Repeti(list):
         pattern = re.compile(r'\b\w*(\w)\1{3,}\w*\b')
         filteredword_list =[]
         for word in list:
            if not pattern.search(word):
               filteredword_list.append(word)
         return filteredword_list
      Rem_repeat = word_Repeti(Rem_punc)
   #------------------------------------------------------------------------------------------
   # 17.Remove single characters and non-English words  
      def remsingle_Noenglish(filtered_word):
         english_words = set(words.words())
         filtered_words = []
         for word in filtered_word:
            if len(word) > 4: 
               filtered_words.append(word)
            elif word.lower() in english_words:
               filtered_words.append(word)
            else:
               continue
         return filtered_words
      Rem_noenglish = remsingle_Noenglish(Rem_repeat)
   #-------------------------------------------------------------------------------------------
   # 18. Remove single-character 
      def remsingle_Words(word_list):
         new_list = []
         other = []
         for word in word_list:
            if len(word) > 1:
               new_list.append(word)
            else:
               other.append(word)
         return new_list
      Rem_single = remsingle_Words(Rem_noenglish)
   #-----------------------------------------------------------------------------------------
   # 19. Remove words with spelling mistakes
      def spelling_Check(word_list):
         spell_checker = enchant.Dict("en")
         global corrected_words 
         for word in word_list:
            if spell_checker.check(word):
               corrected_words.append(word)
         return corrected_words
      corrected_words = spelling_Check(Rem_single )
   #----------------------------------------------------------------------------------------
   # 20. Calculations
      def calculation():
         initial_words = len(split_words)
         total_words = len(filter)
         final_words = len(corrected_words)
         Remain_percentage = (final_words / total_words) * 100
         print("\nTITLE OF THE DOCUMENT \n",title)
         print("\nText Cleaning Results")
         print("Total number of words before split the portion is", initial_words)
         print("Total number of words after split the portion (Abstract to Refrence) is", total_words)
         print("Total number of words after text cleaning is", final_words)
         print("The remaining percentage of the words is", round(Remain_percentage, 2), "%")
      calculation()
   #--------------------------------------------------------------------------------------------
   # 21. Make a data frame for text cleaning steps
      def data_Frame():
         a = len(split_words)
         b = len(filter)
         c = len(lower_words)
         d = len(Rem_cases)
         e = len(Rem_stopwords)
         f = len(Rem_unicodes)
         g = len(Rem_numbers)
         h = len(Rem_special)
         i = len(Rem_url)
         j = len(Rem_punc)
         k = len(Rem_repeat)
         l = len(Rem_noenglish)
         m = len(Rem_single)
         n = len(corrected_words)
    
         function_names = ["Initial_word", "Word_Filter","Word_Lowercase","R_Case", "R_Stopword","R_Unicode", "R_Numbers", "R_Special","R_URL" ,"R_Punctuations","R_Wordrepe","R_Noenglishwords","R_Singlechar","R_Spellingmistakes"]
         word_counts = [a,b,c,d,e,f,g,h,i,j,k,l,m,n]
         df = pd.DataFrame({"Function Name": function_names, "Word Count": word_counts})
         print(df)
         return df
      table = data_Frame()
   #-------------------------------------------------------------------------------------
   # 22. Plot a graph
      def plot_BarGraph(df):
         plt.figure(figsize=(6,6))
         bars = plt.bar(df["Function Name"], df["Word Count"], color='skyblue')
         plt.xlabel('Function Names')
         plt.ylabel('Word Count')
         plt.title('Visualzation Data in Text Cleaning')
         plt.xticks(rotation=90)
      # maximum and minimum values of x values
         max_idx = df["Word Count"].idxmax()
         min_idx = df["Word Count"].idxmin()
      # Highlight the maximum and minimum values 
         bars[max_idx].set_color('green')
         bars[min_idx].set_color('red')
      # Labeling the bars with their respective values
         for bar in bars:
            height = bar.get_height()
            plt.annotate(f'{height}',xy=(bar.get_x() + bar.get_width() / 2, height),xytext=(0, 3),  textcoords="offset points",ha='center', va='bottom')
         plt.tight_layout()
         plt.show()
      plot_BarGraph(table)
   Text_Cleaner()
   
#///////////////////////////////////////////////////////////////////////////////////////////////

# 02. FUNCTION FOR AUTOMATE THE EXTRACTION THE LIST OF EO4GEO BOK CONCEPT AND PRE-PROCSEESING THE EXTRACTED LIST
   
   global title
   global cleaned_list
   cleaned_list =[]
   global concept_names
   concept_names = []
   
   def EO4GEO():
   # 1. automatic list of BOK concept extraction using jason file
      with open('Data.json', 'r', encoding='utf-8') as json_file:
         data = json.load(json_file)
      def EO4GEOlist_extractor(data):
      # Open and load the JSON file with UTF-8 encoding
         names = []
         for key, value in data.items():
            if isinstance(value, dict):
               if 'name' in value:
                  names.append(value['name'])
                  names.extend(EO4GEOlist_extractor(value))
         return names
      global concept_names
      concept_names = EO4GEOlist_extractor(data)
      print("\nList of EO4GEO BOK concept:\n", concept_names)
      print("\nLength of the list of EO4GEO BOK \n",len(concept_names))
   #------------------------------------------------------------------------------------------
   # 2. Convert lower case in the words and phrass in the list
      def lower_EO4GEO(list):
         lst = []
         for x in list:
            x = x.lower()
            lst.append(x)
         return lst
      lower_list = lower_EO4GEO(concept_names)
   #----------------------------------------------------------------------------------------
   # 3. Remove stop words from an element
      def remove_Stopwords(element):
         words = element.split()
         filtered_words = []
         for word in words:
            if word.lower() not in stopwords.words('english'):
               filtered_words.append(word)
         return ' '.join(filtered_words)
      
      remove_stop = []
      for element in lower_list:
         cleaned_element = remove_Stopwords(element)
         remove_stop.append(cleaned_element)
   #------------------------------------------------------------------------------------------
   # 4. Remove punctuations for the elements in the list
      def process_Word(word):
         word = word.replace('-', ' ')
         word = word.replace(',', ' ')
         word = word.replace('/', ' ')
         word = word.replace(':', ' ')
         word = word.replace('()', ' ')
         word = word.replace("'", '')
   
         wordnoPunctuation = ""
         for char in word:
            if char not in string.punctuation:
               wordnoPunctuation += char
         return wordnoPunctuation
   
      processed_lst = []
      for word in remove_stop:
         processed_lst.append(process_Word(word))
   #-----------------------------------------------------------------------------------------
   # 5. Remove extra white spaces
      def clean_Strings(list):
         global cleaned_list
         for element in list:
            cleaned_element = ' '.join(element.split())
            cleaned_list.append(cleaned_element)
         return cleaned_list
      clean_Strings(processed_lst)
      print("\nList of EO4GEO BOK concept after doing text cleaning:\n", cleaned_list)
   EO4GEO()
   
   EO4GEOBOK_keyphrases = cleaned_list
   
#///////////////////////////////////////////////////////////////////////////////////////////////

# 03. FUNCTION FOR AUTOMATIC KEY PHRASE EXTRACTION USING YAKE ALGORITHM
   global x
   x = print("\nText from PDF after text cleaning \n", corrected_words)
   global new_list
   new_list = []
   YAKE_keyphrases = new_list
#-----------------------------------------------------------------------------------  
   def YAKE_Extractor():
# 1. Convert preprocess list from pdf in to one string
      def convert_String(lst):
         text_final = ' '.join(map(str,lst))
         return text_final
      text_final = convert_String(corrected_words)
      print("\nEntire cleaned text as a string \n", text_final)
#----------------------------------------------------------------------------------------
# 2. Automatic keyphrase extraction using YAKE algorithm
      def extractor(text):
         language = "en"
         max_ngram_size = 3
         deduplication_threshold = 0.4
         deduplication_algo = 'seqm'
         windowSize = 1
         numOfKeywords = 100
         kw_extractor = yake.KeywordExtractor(lan=language, n=max_ngram_size, dedupLim=deduplication_threshold, dedupFunc=deduplication_algo, windowsSize=windowSize, top=numOfKeywords, features=None)
         ex_keyphrase = kw_extractor.extract_keywords(text)
         return ex_keyphrase
      kp = extractor(text_final)
#-----------------------------------------------------------------------------------------
# 3. list out all extrated key phrase without YAKE score
      def extractor_Noscore(list):
         global new_list
         for i in list:
            new_list.append(i[0])
         print("\nList of Extracted key phrases using YAKE algorithms are \n", new_list)
         return new_list
      extractor_Noscore(kp)   
   YAKE_Extractor()

#///////////////////////////////////////////////////////////////////////////////////////////////

# 04. FUNCTION FOR LATENT SIMENTIC ANALYSIS SIMILARITY MEASURES
   
   global abovethreshold_phrases
   abovethreshold_phrases = set()
   phrase1_frequency = {}
   
   def LSA_similarity(list1, list2,threshold):
      mappdict_eo4geo = dict(zip(list1, concept_names))
      
      combined_elements = list1 + list2

    # Create a Document-Term Matrix (DTM) 
      vectorizer = CountVectorizer(min_df=1, stop_words='english')
      dtm_combined = vectorizer.fit_transform(combined_elements)

    # Apply TruncatedSVD (LSA) to the combined DTM
      n_components = 2
      lsa = TruncatedSVD(n_components=n_components, algorithm='arpack')
      dtmcombined_lsa = lsa.fit_transform(dtm_combined.astype(float))
      dtmcombined_lsa = Normalizer(copy=False).fit_transform(dtmcombined_lsa)

    # Split the LSA components back into two parts for each list
      dtmlist1_lsa = dtmcombined_lsa[:len(list1)]
      dtmlist2_lsa = dtmcombined_lsa[len(list1):]

    # Compute element-wise similarity using LSA components
      similarity_matrix = np.dot(dtmlist1_lsa, dtmlist2_lsa.T)

    # DataFrame to display the similarity matrix
      df_similarity = pd.DataFrame(similarity_matrix, index=list1, columns=list2)
      df_similarity.to_csv('document_similarity.csv')
    
      print("\nKey Phrases with Similarity > {}:".format(threshold))
      
      similarity_list = []
      countabove_threshold = 0
      for i, phrase1 in enumerate(list1):
         for j, phrase2 in enumerate(list2):
            similarity = similarity_matrix[i, j]
            if similarity > threshold:
               concept_name = mappdict_eo4geo[phrase1]
               similarity_list.append((concept_name, phrase2, similarity))
               countabove_threshold += 1
               abovethreshold_phrases.add(concept_name)
               phrase1_frequency[concept_name] = phrase1_frequency.get(concept_name, 0) + 1
      
      #arrange in to descending order
      similarity_list.sort(key=lambda x: x[2], reverse=True)
      for concept_name, phrase2, similarity in similarity_list:
        print(f"Similarity between '{concept_name}' and '{phrase2}' : {similarity}")
      
      print("\nElement-wise Similarity:")
      print(df_similarity)
      print(f"Total similarity measures above the threshold: {countabove_threshold}")
      print(abovethreshold_phrases)
      print("\nTotal number of EO4GEO BOK concepts match to given pdf:\n",len(abovethreshold_phrases))
      print("\nFrequency of each EO4GEO BOK concepts above the threshold:")
      for concept_name, frequency in phrase1_frequency.items():
         print(f"{concept_name}: {frequency}")
      
   list1 = EO4GEOBOK_keyphrases
   list2 = YAKE_keyphrases

   LSA_similarity(list1, list2, threshold=0.9)
   
#///////////////////////////////////////////////////////////////////////////////////////////////
# 05. FUNCTION FOR CREATE JSON FILE TO DOWNLOAD FINAL OUTPUTS GIVEN BY PROPOSED TOOL

   def Create_Json(doi, title,concepts):
      output_data = {
        "DOI": doi,
        "Title": title,
        "Concepts": list(concepts)
      }

      json_filename = "JSON_YAKELSA.json"

      with open(json_filename, 'w') as json_file:
         json.dump(output_data, json_file, indent=4)

   DOI = http_sections
   TITLE =title
   CONCEPTS = abovethreshold_phrases

   Create_Json(DOI, TITLE, CONCEPTS)

YAKE_LSA('Augustijn-FULL_feedback.pdf')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\Dell\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# Meta data of the PDF
# Total number of pages in the PDF file is:  4
# Author name: None
# Creator name: None
# Producer name: None
#
# Removed Header:
# AGILE: GIScience Series, 4, 19, 2023. https://doi.org/10.5194/agile-giss-4-19-2023
# Proceedings of the 26th AGILE Conference on Geographic Information Science, 2023.
# Editors: P. van Oosterom, H. Ploeger, A. Mansourian, S. Scheider, R. Lemmens, and B. van Loenen.
# This contribution underwent peer review based on a full paper submission.
# © Author(s) 2023. This work is distributed under the Creative Commons Attribution 4.0 License
#
# Removed Footers:
# AGILE: GIScience Series, 4, 19, 2023 | https://doi.org/10.5194/agile-giss-4-19-2023
# AGILE: GIScience Series, 4, 19, 2023 | https://doi.org/10.5194/agile-giss-4-19-2023
# AGILE: GIScience Series, 4, 19, 2023 | https://doi.org/10.5194/agile-giss-4-19-2023
#
#
# DOI of the paper:
# https://doi.org/10.5194/agile-giss-4-19-2023
#
# TITLE OF THE DOCUMENT
#  Using Machine Learning to drive social learning in a Covid 19 Agent Based Model Ellen Wien Augustijn1 , Rosa Aguilar Bolivar1 , and Shaheen Abdulkareem2 1 Department of Geoinformation Processing ( GIP ) , University of Twente , Enschede , The Netherlands 2 Department of computer science , University of Duhok , Duhok , Iraq Correspondence : Ellen Wien Augustijn ( p.w.m.augustijn @ utwente.nl )
#
# Text Cleaning Results
# Total number of words before split the portion is 2897
# Total number of words after split the portion (Abstract to Refrence) is 2376
# Total number of words after text cleaning is 1039
# The remaining percentage of the words is 43.73 %
#          Function Name  Word Count
# 0         Initial_word        2897
# 1          Word_Filter        2376
# 2       Word_Lowercase        2376
# 3               R_Case        2376
# 4           R_Stopword        1629
# 5            R_Unicode        1629
# 6            R_Numbers        1534
# 7            R_Special        1514
# 8                R_URL        1161
# 9       R_Punctuations        1160
# 10          R_Wordrepe        1160
# 11    R_Noenglishwords        1094
# 12        R_Singlechar        1094
# 13  R_Spellingmistakes        1039
# List of EO4GEO BOK concept:
#  ['Analytical Methods', 'Foundations of analytical methods', 'Analytical approaches', 'Data mining', 'Problems of large spatial databases', 'Data mining approaches', 'Knowledge discovery', 'Network analysis', 'Networks defined', 'Graph theoretic descriptive measures of networks', 'Least-cost shortest path', 'Flow modeling', 'The Classic Transportation Problem', 'Other classic network problems', 'Accessibility modeling', 'Optimization and location-allocation modeling', 'Operations research modeling and location modeling principles', 'Linear programming', 'Integer programming', 'Location-allocation modeling and p-median problems', 'Representation transformation', 'Impacts of transformations', 'Data model and format conversion', 'Interpolation', 'Vector-to-raster and raster-to-vector conversions', 'Raster resampling', 'Coordinate transformations', 'Generalization and aggregation', 'Scale and generalization', 'Approaches to point, line, and area generalization', 'Classification and transformation of attribute measurement levels', 'Query operations and query languages', 'Set theory', 'Structured Query Language (SQL) and attribute queries', 'Spatial queries', 'Geometric measures', 'Distances and lengths', 'Direction', 'Shape', 'Area', 'Proximity and distance decay', 'Adjacency and connectivity', 'Basic analytical operations', 'Reclassification and selection operations', 'Buffers', 'Overlay', 'Neighborhood analysis', 'Map algebra', 'Basic analytical methods', 'Point pattern analysis', 'Kernels and density estimation', 'Spatial cluster analysis', 'Spatial interaction', 'Analyzing multidimensional attributes', 'Multi-criteria evaluation', 'Spatial process models', 'Analysis of surfaces', 'Interpolation of surfaces', 'Surface features', 'Intervisibility', 'Friction surfaces', 'Spatial statistics', 'Graphical methods', 'Stochastic processes', 'The spatial weights matrix', 'Global measures of spatial association', 'Local measures of spatial association', 'Outliers', 'Bayesian methods', 'Geostatistics', 'Spatial sampling for statistical analysis', 'Variogram modeling', 'Principles of kriging', 'Kriging variants', 'Spatial regression and econometrics', 'Principles of spatial econometrics', 'Spatial autoregressive models', 'Spatial filtering', 'Spatial expansion and Geographically Weighted Regression GWR', 'Conceptual Foundations', 'Philosophical foundations', 'Metaphysics and ontology', 'What is Geographic Information Science and Technology', 'Epistemology', 'Contributions to GIS and T by key allied fields', 'Philosophical perspectives', 'Introduction to Geographic Information Science and Technology', 'Cognitive and social foundations', 'Perception and cognition of geographic phenomena', 'Philosophy of being', 'From concepts to data', 'Philosophy of knowledge', 'Geography as a foundation for GIS', 'Place and landscape', 'Cultural influences', 'Political influences', 'Cognitive, linguistic and social foundations', 'Space', 'Cognitive foundations', 'Linguistic foundations', 'Social foundations', 'Common-sense geographies', 'Time', 'Relationships between space and time', 'Categories', 'Properties', 'Fundamentals of Geographic Information', 'Discrete entities', 'Fields', 'Events and processes', 'Integrated models', 'Spatial distribution', 'Region', 'Spatial integration', 'Elements of geographic information', 'Relationships', 'Mereology: structural relationships', 'Genealogical relationships: lineage, inheritance', 'Topological relationships', 'Metrical relationships: distance and direction', 'Imperfections in geographic information', 'Vagueness', 'Error-based uncertainty', 'Cartography and Visualization', 'History and trends', 'History and evolution of cartography', 'Art and geodata visualisation', 'Historical maps', 'Data considerations', 'Data sources for mapping', 'Data processing', 'Mathematical base', 'Design principles', 'Map design fundamentals', 'Geo-gaming', 'Symbols and icons', 'Colour', 'Typography', 'Photos and imagery', 'Animation' ...
#
# Length of the list of EO4GEO BOK
#  952
#
# List of EO4GEO BOK concept after doing text cleaning:
#  ['analytical methods', 'foundations analytical methods', 'analytical approaches', 'data mining', 'problems large spatial databases', 'data mining approaches', 'knowledge discovery', 'network analysis', 'networks defined', 'graph theoretic descriptive measures networks', 'least cost shortest path', 'flow modeling', 'classic transportation problem', 'classic network problems', 'accessibility modeling', 'optimization location allocation modeling', 'operations research modeling location modeling principles', 'linear programming', 'integer programming', 'location allocation modeling p median problems', 'representation transformation', 'impacts transformations', 'data model format conversion', 'interpolation', 'vector to raster raster to vector conversions', 'raster resampling', 'coordinate transformations', 'generalization aggregation', 'scale generalization', 'approaches point line area generalization', 'classification transformation attribute measurement levels', 'query operations query languages', 'set theory', 'structured query language sql attribute queries', 'spatial queries', 'geometric measures', 'distances lengths', 'direction', 'shape', 'area', 'proximity distance decay', 'adjacency connectivity', 'basic analytical operations', 'reclassification selection operations', 'buffers', 'overlay', 'neighborhood analysis', 'map algebra', 'basic analytical methods', 'point pattern analysis', 'kernels density estimation', 'spatial cluster analysis', 'spatial interaction', 'analyzing multidimensional attributes', 'multi criteria evaluation', 'spatial process models', 'analysis surfaces', 'interpolation surfaces', 'surface features', 'intervisibility', 'friction surfaces', 'spatial statistics', 'graphical methods', 'stochastic processes', 'spatial weights matrix', 'global measures spatial association', 'local measures spatial association', 'outliers', 'bayesian methods', 'geostatistics', 'spatial sampling statistical analysis', 'variogram modeling', 'principles kriging', 'kriging variants', 'spatial regression econometrics', 'principles spatial econometrics', 'spatial autoregressive models', 'spatial filtering', 'spatial expansion geographically weighted regression gwr', 'conceptual foundations', 'philosophical foundations', 'metaphysics ontology', 'geographic information science technology', 'epistemology', 'contributions gis key allied fields', 'philosophical perspectives', 'introduction geographic information science technology', 'cognitive social foundations', 'perception cognition geographic phenomena', 'philosophy', 'concepts data', 'philosophy knowledge', 'geography foundation gis', 'place landscape', 'cultural influences', 'political influences', 'cognitive linguistic social foundations', 'space', 'cognitive foundations', 'linguistic foundations', 'social foundations', 'common sense geographies', 'time', 'relationships space time', 'categories', 'properties', 'fundamentals geographic information', 'discrete entities', 'fields', 'events processes', 'integrated models', 'spatial distribution', 'region', 'spatial integration', 'elements geographic information', 'relationships', 'mereology structural relationships', 'genealogical relationships lineage inheritance', 'topological relationships', 'metrical relationships distance direction', 'imperfections geographic information', 'vagueness', 'error based uncertainty', 'cartography visualization', 'history trends', 'history evolution cartography', 'art geodata visualisation', 'historical maps', 'data considerations', 'data sources mapping', 'data processing', 'mathematical base', 'design principles', 'map design fundamentals', 'geo gaming', 'symbols icons', 'colour', 'typography', 'photos imagery', 'animation', 'sound', 'storytelling', 'infographics', 'graphic representation techniques', 'thematic mapping', 'visualization uncertainty', 'representing terrain', 'multivariate displays', 'visualization temporal geographic data', 'dynamic interactive displays', 'web mapping', 'virtual im ...
#
# Text from PDF after text cleaning
#  ['disease', 'transmission', 'governmental', 'interventions', 'influence', 'spread', 'models', 'essential', 'tools', 'optimise', 'governmental', 'interventions', 'requires', 'exploration', 'various', 'ways', 'implement', 'government', 'agent', 'behaviour', 'agent', 'based', 'models', 'government', 'agent', 'behaviour', 'rule', 'based', 'data', 'driven', 'agent', 'isolated', 'learner', 'using', 'data', 'social', 'learner', 'explore', 'creation', 'data', 'driven', 'social', 'approach', 'behaviour', 'based', 'machine', 'learning', 'algorithm', 'government', 'considers', 'data', 'countries', 'input', 'decision', 'making', 'governmental', 'actions', 'start', 'risk', 'perception', 'based', 'several', 'parameters', 'number', 'disease', 'cases', 'deaths', 'hospitalisation', 'rate', 'interventions', 'measured', 'via', 'stringency', 'index', 'measuring', 'simultaneous', 'number', 'interventions', 'working', 'home', 'wearing', 'closing', 'schools', 'taken', 'test', 'four', 'machine', 'learning', 'algorithms', 'network', 'nave', 'random', 'forest', 'using', 'class', 'class', 'classification', 'stringency', 'level', 'algorithms', 'trained', 'disease', 'data', 'many', 'countries', 'best', 'performing', 'algorithms', 'next', 'step', 'implement', 'algorithms', 'evaluate', 'outcomes', 'compared', 'original', 'model', 'keywords', 'agent', 'based', 'modelling', 'machine', 'learning', 'introduction', 'pandemic', 'learned', 'governments', 'play', 'important', 'role', 'disease', 'interventions', 'enforce', 'make', 'wearing', 'face', 'masks', 'mandatory', 'implement', 'vaccination', 'campaigns', 'governmental', 'decision', 'making', 'based', 'strategy', 'risk', 'perception', 'coping', 'appraisal', 'governments', 'decide', 'risk', 'level', 'based', 'disease', 'incidence', 'number', 'available', 'hospital', 'understand', 'impact', 'governmental', 'decisions', 'disease', 'diffusion', 'need', 'integrate', 'disease', 'models', 'policy', 'models', 'agent', 'based', 'models', 'good', 'tools', 'modelling', 'bottom', 'disease', 'diffusion', 'personal', 'decision', 'making', 'many', 'cases', 'governments', 'modelled', 'agents', 'included', 'governments', 'modelled', 'isolated', 'entities', 'apply', 'rule', 'based', 'behaviour', 'decide', 'interventions', 'use', 'however', 'decision', 'making', 'might', 'social', 'activity', 'governments', 'various', 'countries', 'collaborate', 'share', 'experiences', 'social', 'agents', 'interactive', 'communicate', 'neighbours', 'case', 'governments', 'learn', 'effectively', 'within', 'groups', 'complicating', 'factor', 'pandemic', 'beginning', 'nobody', 'much', 'experience', 'policies', 'effective', 'disease', 'control', 'simulate', 'learning', 'process', 'intelligence', 'government', 'agent', 'increase', 'simulation', 'type', 'learning', 'best', 'achieved', 'replacing', 'rule', 'based', 'agent', 'decision', 'making', 'machine', 'learning', 'algorithm', 'learns', 'directly', 'data', 'implementing', 'agent', 'learning', 'via', 'many', 'decisions', 'made', 'concerning', 'type', 'algorithm', 'data', 'used', 'train', 'algorithm', 'architecture', 'linking', 'research', 'take', 'first', 'step', 'replacing', 'isolated', 'government', 'agent', 'rule', 'based', 'decision', 'making', 'model', 'algorithm', 'drives', 'government', 'agent', 'decisions', 'situation', 'exchange', 'information', 'governments', 'takes', 'place', 'testing', 'several', 'algorithms', 'depict', 'governmental', 'risk', 'perception', 'methods', 'agent', 'based', 'model', 'hybrid', 'compartmental', 'simulating', 'diffusion', 'model', 'contains', 'three', 'sub', 'models', 'population', 'interaction', 'model', 'disease', 'model', 'mobility', 'model', 'simulated', 'population', 'divided', 'nine', 'age', 'categories', 'split', 'commuters', 'non', 'commuters', 'disease', 'diffusion', 'modelled', 'using', 'susceptible', 'infected', 'recovered', 'sir', 'model', 'using', 'age', 'dependent', 'transmission', 'rates', 'four', 'types', 'mobility', 'implemented', 'different',  ...
#
# Entire cleaned text as a string
#  disease transmission governmental interventions influence spread models essential tools optimise governmental interventions requires exploration various ways implement government agent behaviour agent based models government agent behaviour rule based data driven agent isolated learner using data social learner explore creation data driven social approach behaviour based machine learning algorithm government considers data countries input decision making governmental actions start risk perception based several parameters number disease cases deaths hospitalisation rate interventions measured via stringency index measuring simultaneous number interventions working home wearing closing schools taken test four machine learning algorithms network nave random forest using class class classification stringency level algorithms trained disease data many countries best performing algorithms next step implement algorithms evaluate outcomes compared original model keywords agent based modelling machine learning introduction pandemic learned governments play important role disease interventions enforce make wearing face masks mandatory implement vaccination campaigns governmental decision making based strategy risk perception coping appraisal governments decide risk level based disease incidence number available hospital understand impact governmental decisions disease diffusion need integrate disease models policy models agent based models good tools modelling bottom disease diffusion personal decision making many cases governments modelled agents included governments modelled isolated entities apply rule based behaviour decide interventions use however decision making might social activity governments various countries collaborate share experiences social agents interactive communicate neighbours case governments learn effectively within groups complicating factor pandemic beginning nobody much experience policies effective disease control simulate learning process intelligence government agent increase simulation type learning best achieved replacing rule based agent decision making machine learning algorithm learns directly data implementing agent learning via many decisions made concerning type algorithm data used train algorithm architecture linking research take first step replacing isolated government agent rule based decision making model algorithm drives government agent decisions situation exchange information governments takes place testing several algorithms depict governmental risk perception methods agent based model hybrid compartmental simulating diffusion model contains three sub models population interaction model disease model mobility model simulated population divided nine age categories split commuters non commuters disease diffusion modelled using susceptible infected recovered sir model using age dependent transmission rates four types mobility implemented different age groups school commuting job commuting gathering event commuting visit travelling commuting types match different intervention strategies model contains government agent performs risk perception coping strategies based theories rogers al risk based two variables number positive tests per inhabitants per week number hospitalised individuals per day recognises five risk levels based road map used dutch government van model implemented predicts daily number disease cases dutch municipalities data combined two open source one government interventions hale one number disease cases countries data provided hale al provides stringency index stringency index based nine metrics including school closures workplace closures restrictions kinds movements scale zero stringency index expresses severity restricting measures governments apply assume stricter measures risk stringency index calculated daily figure overview methods risk perception model based three aspects number disease cases per inhabitants number per inhabitants number deaths per inhabitants precis ...
#
# List of Extracted key phrases using YAKE algorithms are
#  ['number disease cases', 'fold cross validation', 'disease cases number', 'cases number deaths', 'tests hospitalised individuals', 'risk perception coping', 'government agent decisions', 'split training testing', 'nave random forest', 'evaluate importance features', 'machine learning algorithm', 'inhabitants number hospitalised', 'perception disease diffusion', 'cases deaths hospitalisation', 'agent based models', 'trained fold cross', 'decision making machine', 'index stringency index', 'trees trained fold', 'learning case government', 'stringency index stringency', 'personal decision making', 'impact risk perception', 'aim simulate disease', 'cases governments modelled', 'validation split training', 'cases smallest impact', 'communicate neighbours case', 'diffusion personal decision', 'role disease interventions', 'step implement trained', 'based machine learning', 'behaviour rule based', 'rule based behaviour', 'risk level based', 'trees higher accuracy', 'index calculated daily', 'original evaluates risk', 'making strategy future', 'driven agent isolated', 'decide risk level', 'implement government agent', 'achieved replacing rule', 'precisely match rule', 'keywords agent based', 'index expresses severity', 'individuals considered ultimate', 'part test split', 'agent gradually learn', 'agent increase simulation', 'top normalized number', 'experiences social agents', 'hospitalisation rate intensive', 'network nave random', 'forest algorithms trained', 'class classification stringency', 'importance features determine', 'test separately evaluate', 'overview methods risk', 'algorithm accuracy fold', 'ultimate aim integrate', 'categories split commuters', 'training processes nave', 'actions start risk', 'interaction model disease', 'learning introduction pandemic', 'outcomes compared original', 'set countries fewer', 'dependent transmission rates', 'hypothetical situation dutch', 'output represent hypothetical', 'aim create intelligent', 'rate intensive care', 'target variable classified', 'accuracy table explainable', 'modelled isolated entities', 'daily figure overview', 'accuracy correctly predicted', 'driven social approach', 'masks mandatory implement', 'commuting types match', 'steering behaviour relation', 'based road map', 'travelling commuting types', 'data driven agent', 'discussion based results', 'tools modelling bottom', 'age groups school', 'closures workplace closures', 'explainable nave effective', 'halfway graph countries', 'countries collaborate share', 'countries united kingdom', 'compared actual class', 'strategy future pandemics', 'processes nave showed', 'groups school commuting', 'natural breaks classification', 'situation exchange information', 'simulated population divided']
#
# Key Phrases with Similarity > 0.9:
# Similarity between 'Users in local & regional planning' and 'part test split' : 0.9999999999501556
# Similarity between 'DSM generation' and 'cases deaths hospitalisation' : 0.9999999998692685
# Similarity between 'Next-generation SDIs' and 'cases deaths hospitalisation' : 0.9999999998692685
# Similarity between 'Users in humanitarian operations' and 'part test split' : 0.9999999997844019
# Similarity between 'Users in ICT, knowledge and digital interfaces' and 'split training testing' : 0.9999999992306027
# Similarity between 'Product quality' and 'algorithm accuracy fold' : 0.999999999194544
# Similarity between 'Quality indicators' and 'algorithm accuracy fold' : 0.999999999194544
# Similarity between 'Open data' and 'data driven agent' : 0.9999999990047385
# Similarity between 'Drivers and incentives for sharing geospatial data' and 'class classification stringency' : 0.9999999984331381
# Similarity between 'Vegetation fraction' and 'learning introduction pandemic' : 0.9999999973005261
# Similarity between 'Kriging variants' and 'daily figure overview' : 0.9999999922959031
# Similarity between 'Metadata and standards' and 'aim create intelligent' : 0.9999999917621537
# Similarity between 'Least-cost shortest path' and 'algorithm accuracy fold' : 0.9999999917588023
# Similarity between 'History of remote sensing data carriers' and 'test separately evaluate' : 0.9999999866064415
# Similarity between 'Reflection, Refraction and Dispersion of the light' and 'categories split commuters' : 0.9999999835525624
# Similarity between 'Atmospheric correction' and 'inhabitants number hospitalised' : 0.9999999828254875
# Similarity between 'Users among citizens & society' and 'split training testing' : 0.9999999785265569
# Similarity between 'Digital Frame Camera' and 'nave random forest' : 0.999999973975634
# Similarity between 'Doppler Wind LiDAR' and 'agent increase simulation' : 0.9999999569400164
# Similarity between 'Digital twin' and 'nave random forest' : 0.9999999530710616
# Similarity between 'Users in emergency & social protection' and 'part test split' : 0.9999999448455764
# Similarity between 'Strategic planning' and 'rate intensive care' : 0.9999999348387254
# Similarity between 'Mission planning' and 'rate intensive care' : 0.9999999348387254
# Similarity between 'Geometrically measured EO products' and 'set countries fewer' : 0.9999999308707943
# Similarity between 'Monitor urban areas' and 'forest algorithms trained' : 0.9999999212473359
# Similarity between 'Application models based on vector data' and 'aim simulate disease' : 0.9999999152642353
# Similarity between 'Watershed segmentation' and 'accuracy correctly predicted' : 0.9999999145049646
# Similarity between 'Publishing linked open data' and 'test separately evaluate' : 0.9999999135510347
# Similarity between 'Organizations in the GIS and T domain' and 'index expresses severity' : 0.9999998947257362
# Similarity between 'Web application Frameworks and Geoportal frameworks' and 'machine learning algorithm' : 0.9999998925618869
# Similarity between 'Users in infrastructure & transport' and 'forest algorithms trained' : 0.9999998774926678
# Similarity between 'Spatial integration' and 'agent increase simulation' : 0.9999998568599718
# Similarity between 'Food security monitoring' and 'rate intensive care' : 0.9999998526279334
# Similarity between 'Synthetic Aperture Radar (SAR) spatial resolution' and 'discussion based results' : 0.9999998518973487
# Similarity between 'Legal instruments for sharing geospatial data' and 'compared actual class' : 0.9999998512883683
# Similarity between 'Earth Observation Big Data' and 'data driven agent' : 0.9999998503808558
# Similarity between 'Types of remote sensing sensors' and 'aim create intelligent' : 0.9999998477160458
# Similarity between 'Geometrically corrected' and 'experiences social agents' : 0.9999998261968617
# Similarity between 'Users in ICT, knowledge and digital interfaces' and 'training processes nave' : 0.99999982234355
# Similarity between 'Error-based uncertainty' and 'risk level based' : 0.9999998206936688
# Similarity between 'Users in ICT, knowledge and digital interfaces' and 'validation split training' : 0.9999998197988623
# Similarity between 'Atmospheric correction' and 'top normalized number' : 0.9999998194125979
# Similarity between 'Knowledge representation' and 'hospitalisation rate intensive' : 0.9999998152256023
# Similarity between 'Users in news & media' and 'part test split' : 0.9999997958094319
# Similarity between 'EO for sustainable urban development' and 'top normalized number' : 0.9999997949344832
# Similarity between 'Cloud mask' and 'learning introduction pandemic' : 0.9999997898360604
# Similarity between 'Thermodynamics diagram, atmosphere static' and 'nave random forest' : 0.9999997737489317
# Similarity between 'User roles' and 'countries united kingdom' : 0.9999997642202745
# Similarity between 'User roles' and 'countries collaborate share' : 0.9999997642202714
# Similarity between 'Surface roughness slope' and 'strategy future pandemics' : 0.999999760503849
# Similarity between 'Foundations for Data Modelling Storage and Exploitation' and 'data driven agent' : 0.9999997589094578
# Similarity between 'Social critiques' and 'experiences social agents' : 0.9999997555870771
# Similarity between 'Coordinating GIS Participants and Users' and 'validation split training' : 0.9999997546860295
# Similarity between 'Coordinating GIS Participants and Users' and 'training processes nave' : 0.9999997516973799
# Similarity between 'EO for sustainable agriculture & food production' and 'cases smallest impact' : 0.9999997235669906
# Similarity between 'Class stability' and 'compared actual class' : 0.999999715293751
# Similarity between 'EO-derived attribute products' and 'individuals considered ultimate' : 0.9999997057930636
# Similarity between 'Extract information about subsurface geology' and 'driven social approach' : 0.9999996837371976
# Similarity between 'GIS and T curriculum and course design' and 'cases deaths hospitalisation' : 0.9999996799288967
# Similarity between 'Structured-light-projection camera' and 'age groups school' : 0.9999996664677316
# Similarity between 'Difference of Gaussian (DoG)' and 'explainable nave effective' : 0.9999996633828382
# Similarity between 'Users in environmental, climate & health' and 'part test split' : 0.9999996557284705
# Similarity between 'Interaction of microwaves with matter' and 'original evaluates risk' : 0.9999996482255498
# Similarity between 'Satellite and shipboard remote sensing' and 'aim create intelligent' : 0.9999996474618386
# Similarity between 'Monitor land use' and 'making strategy future' : 0.9999996463681373
# Similarity between 'Planck law for the black body. Wien's displacement law' and 'categories split commuters' : 0.9999996457756134
# Similarity between 'Users in managed living resources' and 'rate intensive care' : 0.9999996457526728
# Similarity between 'Users among citizens & society' and 'training processes nave' : 0.9999996450589161
# Similarity between 'Users among citizens & society' and 'validation split training' : 0.9999996414658089
# Similarity between 'Theory of mind' and 'learning introduction pandemic' : 0.9999996391566
# Similarity between 'Vector data model, Feature based modelling, Applications' and 'algorithm accuracy fold' : 0.9999996362121565
# Similarity between 'Users in energy and mineral resources' and 'rate intensive care' : 0.9999996353977171
# Similarity between 'Users in defense, security & military' and 'rate intensive care' : 0.999999627738609
# Similarity between 'Colour' and 'validation split training' : 0.9999996262934978
# Similarity between 'Colour' and 'training processes nave' : 0.9999996226068676
# Similarity between 'Discovery over linked open data' and 'data driven agent' : 0.9999996191646696
# Similarity between 'Legal framework for geospatial data sharing' and 'compared actual class' : 0.9999996131519244
# Similarity between 'Philosophy of being' and 'part test split' : 0.9999996104607043
# Similarity between 'Users in defense & security' and 'rate intensive care' : 0.9999995794378008
# Similarity between 'Basics of Thermodynamics' and 'driven agent isolated' : 0.9999995728860142
# Similarity between 'Molecular absorption spectra' and 'index calculated daily' : 0.9999995604565698
# Similarity between 'Users in alternative energy' and 'rate intensive care' : 0.9999995583337226
# Similarity between 'Time' and 'agent gradually learn' : 0.9999995579084474
# Similarity between 'Interaction of microwaves with matter' and 'actions start risk' : 0.9999995440977436
# Similarity between 'Vegetation fraction' and 'countries collaborate share' : 0.9999995439191567
# Similarity between 'Vegetation fraction' and 'countries united kingdom' : 0.9999995439191524
# Similarity between 'Users in oil & gas' and 'rate intensive care' : 0.9999995394474431
# Similarity between 'Users in communications & connectivity' and 'rate intensive care' : 0.9999995378311457
# Similarity between 'Users in smart cities' and 'rate intensive care' : 0.9999995355640543
# Similarity between 'Users in utilities & supplies' and 'rate intensive care' : 0.9999995355640542
# Similarity between 'Users in travel & tourism' and 'rate intensive care' : 0.9999995355640542
# Similarity between 'Geometry data types according to spatial schema and the simple feature specification' and 'aim create intelligent' : 0.9999995349767351
# Similarity between 'Set theory' and 'learning introduction pandemic' : 0.9999995332498407
# Similarity between 'Users in health care' and 'rate intensive care' : 0.9999995046040097
# Similarity between 'Database design' and 'number disease cases' : 0.9999995026497541
# Similarity between 'Database design' and 'disease cases number' : 0.9999995026497538
# Similarity between 'Users of consumer solutions' and 'rate intensive care' : 0.999999501984647
# Similarity between 'Multi-looked Detected (MLD)' and 'precisely match rule' : 0.9999994898478051
# Similarity between 'Users in urban development' and 'hospitalisation rate intensive' : 0.999999488618917
# Similarity between 'Seismic sensor' and 'achieved replacing rule' : 0.999999482489587
# Similarity between 'Users in fishing' and 'rate intensive care' : 0.9999994781724094
# Similarity between 'Users in forestry' and 'rate intensive care' : 0.9999994781724094
# Similarity between 'Users in construction' and 'rate intensive care' : 0.9999994781724094
# Similarity between 'Users in leisure' and 'rate intensive care' : 0.9999994781724094
# Similarity between 'EO for biodiversity & ecosystems' and 'cases smallest impact' : 0.9999994762506114
# Similarity between 'Principles of computer simulation' and 'class classification stringency' : 0.9999994715893594
# Similarity between 'Users in meteo & climate' and 'rate intensive care' : 0.9999994705291976
# Similarity between 'Multi-looked Detected (MLD)' and 'trees trained fold' : 0.9999994474083175
# Similarity between 'Desktop GIS, GIS libraries' and 'index expresses severity' : 0.9999994471142984
# Similarity between 'Users in retail & geo-marketing' and 'part test split' : 0.999999446086869
# Similarity between 'Crowdsourced data collection' and 'data driven agent' : 0.9999994422251701
# Similarity between 'Users in marine' and 'rate intensive care' : 0.9999994355879721
# Similarity between 'Physics aware AI' and 'index calculated daily' : 0.9999994308517043
# Similarity between 'Data quality' and 'data driven agent' : 0.9999994280794453
# Similarity between 'Feature based modelling' and 'agent gradually learn' : 0.9999994261421924
# Similarity between 'Users in agriculture' and 'rate intensive care' : 0.9999994255251
# Similarity between 'Mathematical base' and 'rule based behaviour' : 0.9999994239890303
# Similarity between 'Conditional probability' and 'rule based behaviour' : 0.9999994239890302
# Similarity between 'Mathematical base' and 'behaviour rule based' : 0.9999994239890301
# Similarity between 'Conditional probability' and 'behaviour rule based' : 0.99999942398903
# Similarity between 'Intelligent Software Agent' and 'data driven agent' : 0.9999994222872521
# Similarity between 'Spatial cluster analysis' and 'keywords agent based' : 0.9999994124677861
# Similarity between 'Monitor critical assets' and 'output represent hypothetical' : 0.999999411006465
# Similarity between 'Public participation GIS' and 'categories split commuters' : 0.9999994004298286
# Similarity between 'Image as a matrix (digital number DN)' and 'driven social approach' : 0.9999993922985697
# Similarity between 'Fundamentals of Geographic Information' and 'situation exchange information' : 0.9999993774433816
# Similarity between 'Geolocating Data to Earth' and 'data driven agent' : 0.9999993385184562
# Similarity between 'Data quality standards' and 'data driven agent' : 0.9999993325500777
# Similarity between 'Monitor the atmosphere and climate' and 'hospitalisation rate intensive' : 0.999999318010409
# Similarity between 'Integrating data from OGC web services' and 'compared actual class' : 0.9999992987872517
# Similarity between 'Integrated models' and 'based road map' : 0.999999287489642
# Similarity between 'Markov models' and 'based road map' : 0.999999287489642
# Similarity between 'Mathematical models of uncertainty: Probability and statistics' and 'modelled isolated entities' : 0.9999992848562939
# Similarity between 'Users in insurance & real estate' and 'part test split' : 0.9999992766402467
# Similarity between 'Ideal gas laws' and 'rate intensive care' : 0.9999992763128012
# Similarity between 'Users in environmental ecosystems & pollution' and 'split training testing' : 0.999999274852567
# Similarity between 'Sensing of EM radiation.' and 'algorithm accuracy fold' : 0.9999992737505929
# Similarity between 'Adjacency and connectivity' and 'rate intensive care' : 0.9999992602762947
# Similarity between 'Users in transport & logistics' and 'part test split' : 0.9999992537237938
# Similarity between 'Users in environmental ecosystems & pollution' and 'part test split' : 0.9999992439579612
# Similarity between 'Range direction' and 'strategy future pandemics' : 0.9999992414152429
# Similarity between 'Requirements gathering and analysis' and 'outcomes compared original' : 0.999999238044709
# Similarity between 'Kernel analysis (convolution)' and 'outcomes compared original' : 0.999999238044709
# Similarity between 'Semantic 3D models' and 'tools modelling bottom' : 0.9999992239448224
# Similarity between 'Users in minerals & mining' and 'forest algorithms trained' : 0.9999992231743692
# Similarity between 'Application models based on vector data' and 'role disease interventions' : 0.9999992228106325
# Similarity between 'Geography as a foundation for GIS' and 'index expresses severity' : 0.9999992122615595
# Similarity between 'Ongoing GIS revision' and 'index expresses severity' : 0.9999992122615594
# Similarity between 'GIS and T workforce themes' and 'index expresses severity' : 0.9999992122615594
# Similarity between 'GIS and T positions and qualifications' and 'index expresses severity' : 0.9999992122615594
# Similarity between 'Data storage' and 'data driven agent' : 0.9999992037990114
# Similarity between 'Scale space analysis' and 'outcomes compared original' : 0.9999991829773909
# Similarity between 'Object features' and 'achieved replacing rule' : 0.9999991699410367
# Similarity between 'Helmotz’s equations; Scattering from inhomogeneous media.' and 'cases smallest impact' : 0.999999166006583
# Similarity between 'OGC standards' and 'groups school commuting' : 0.9999991597081451
# Similarity between 'EO for water sustainability' and 'output represent hypothetical' : 0.9999991314920735
# Similarity between 'Monitor fisheries' and 'nave random forest' : 0.9999991053285081
# Similarity between 'Monitor borders' and 'nave random forest' : 0.999999105328508
# Similarity between 'Monitor crops' and 'nave random forest' : 0.999999105328508
# Similarity between 'Monitor topography' and 'nave random forest' : 0.9999991053285079
# Similarity between 'Coordinating GIS Participants and Users' and 'split training testing' : 0.9999991021853638
# Similarity between 'Stochastic processes' and 'rate intensive care' : 0.9999990627910941
# Similarity between 'Events and processes' and 'rate intensive care' : 0.9999990627910941
# Similarity between 'State function of the condensed gas phase' and 'part test split' : 0.9999990596787789
# Similarity between 'Elements of the theory of interference and interferometers' and 'age groups school' : 0.9999990453886244
# Similarity between 'The hexagonal model' and 'accuracy table explainable' : 0.9999990395052929
# Similarity between 'Monitor the forest' and 'nave random forest' : 0.9999990253914713
# Similarity between 'Philosophical foundations' and 'daily figure overview' : 0.9999990222797523
# Similarity between 'Error-based uncertainty' and 'discussion based results' : 0.9999990163572501
# Similarity between 'Philosophy of knowledge' and 'validation split training' : 0.9999990117075928
# Similarity between 'Philosophy of knowledge' and 'training processes nave' : 0.9999990057180139
# Similarity between 'Knowledge organising system' and 'validation split training' : 0.9999990039272109
# Similarity between 'Knowledge organising system' and 'training processes nave' : 0.9999989979141373
# Similarity between 'EO for sustainable urban development' and 'inhabitants number hospitalised' : 0.9999989822239774
# Similarity between 'Requirements gathering and analysis' and 'masks mandatory implement' : 0.9999989747505861
# Similarity between 'Kernel analysis (convolution)' and 'masks mandatory implement' : 0.9999989747505861
# Similarity between 'Social Media Geographic Information' and 'making strategy future' : 0.9999989697845906
# Similarity between 'Monitor the atmosphere' and 'nave random forest' : 0.9999989680102418
# Similarity between 'Data model and format conversion' and 'test separately evaluate' : 0.9999989677220972
# Similarity between 'Open data cube' and 'data driven agent' : 0.9999989569048598
# Similarity between 'Planar geometric features' and 'accuracy correctly predicted' : 0.9999989564351426
# Similarity between 'Integrating data from OGC web services' and 'class classification stringency' : 0.9999989459842912
# Similarity between 'System design' and 'strategy future pandemics' : 0.9999989265758901
# Similarity between 'Geo-gaming' and 'forest algorithms trained' : 0.9999989157144835
# Similarity between 'GEO QA4EO' and 'forest algorithms trained' : 0.9999989157144835
# Similarity between 'Publishing open data' and 'test separately evaluate' : 0.9999988953994967
# Similarity between 'Classification features and feature space' and 'government agent decisions' : 0.9999988797721964
# Similarity between 'Users in financial & digital services' and 'cases smallest impact' : 0.9999988727905802
# Similarity between 'Colour' and 'split training testing' : 0.9999988688520953
# Similarity between 'Polarimetric decomposition techniques' and 'aim create intelligent' : 0.99999885562453
# Similarity between 'Atomic spectroscopy' and 'travelling commuting types' : 0.9999988378801453
# Similarity between 'Publishing open data' and 'data driven agent' : 0.9999988262708859
# Similarity between 'State function of the condensed gas phase' and 'rate intensive care' : 0.9999987872530246
# Similarity between 'Stochastic processes' and 'part test split' : 0.999998783712995
# Similarity between 'Events and processes' and 'part test split' : 0.9999987837129949
# Similarity between 'Data Collection' and 'data driven agent' : 0.9999987720066547
# Similarity between 'Open data cube' and 'test separately evaluate' : 0.9999987610812636
# Similarity between 'Doppler effect' and 'index stringency index' : 0.9999987427701996
# Similarity between 'Knowledge representation' and 'explainable nave effective' : 0.9999987319534562
# Similarity between 'Users in environmental, climate & health' and 'split training testing' : 0.9999987133270469
# Similarity between 'Assess and monitor volcanic activities' and 'nave random forest' : 0.9999987086008995
# Similarity between 'Standard EO products' and 'set countries fewer' : 0.9999986749128184
# Similarity between 'Surface correlation function' and 'cases governments modelled' : 0.9999986712785046
# Similarity between 'Semi automated and Full-automated WSC' and 'role disease interventions' : 0.9999986669115292
# Similarity between 'Vector fields' and 'aim create intelligent' : 0.9999986614912473
# Similarity between 'Einstein’s theory of radiation: photons, photoelectric effect, absorption, emission; Stimulated emission: the laser' and 'countries united kingdom' : 0.9999986086364467
# Similarity between 'Einstein’s theory of radiation: photons, photoelectric effect, absorption, emission; Stimulated emission: the laser' and 'countries collaborate share' : 0.9999986086364393
# Similarity between 'Cloud mask' and 'countries collaborate share' : 0.999998594043558
# Similarity between 'Cloud mask' and 'countries united kingdom' : 0.9999985940435505
# Similarity between 'Standards for Spatial Data Modeling' and 'algorithm accuracy fold' : 0.9999985603044237
# Similarity between 'Users in transport & logistics' and 'rate intensive care' : 0.9999985429657833
# Similarity between 'Classification features and feature space' and 'implement government agent' : 0.9999985392409871
# Similarity between 'User roles' and 'learning introduction pandemic' : 0.9999985289573415
# Similarity between 'Users in insurance & real estate' and 'rate intensive care' : 0.9999985105166151
# Similarity between 'Solar constant, solar insolation, daily insolation' and 'experiences social agents' : 0.9999985051245022
# Similarity between 'Map algebra' and 'number disease cases' : 0.9999984818617866
# Similarity between 'Map reproduction' and 'number disease cases' : 0.9999984818617866
# Similarity between 'Map projections' and 'number disease cases' : 0.9999984818617866
# Similarity between 'Map algebra' and 'disease cases number' : 0.9999984818617865
# Similarity between 'Map projections' and 'disease cases number' : 0.9999984818617865
# Similarity between 'Map reproduction' and 'disease cases number' : 0.9999984818617864
# Similarity between 'Data compression techniques' and 'data driven agent' : 0.9999984311312379
# Similarity between 'Hyperspectral Radiometers' and 'algorithm accuracy fold' : 0.9999984250741589
# Similarity between 'Random forest (RF)' and 'experiences social agents' : 0.9999984211030066
# Similarity between 'Topological modelling' and 'tools modelling bottom' : 0.999998418439851
# Similarity between 'Forecast and assess landslides' and 'cases smallest impact' : 0.9999983935660943
# Similarity between 'Web-based GI' and 'daily figure overview' : 0.9999983694494339
# Similarity between 'EO for societal and environmental challenges' and 'experiences social agents' : 0.9999983631038474
# Similarity between 'Temporal resolution' and 'ultimate aim integrate' : 0.9999983421099391
# Similarity between 'Diffraction' and 'categories split commuters' : 0.999998338308045
# Similarity between 'Helmotz’s equations; Scattering from inhomogeneous media.' and 'nave random forest' : 0.9999983090697704
# Similarity between 'Users in environmental ecosystems & pollution' and 'training processes nave' : 0.9999983079534431
# Similarity between 'Users in environmental ecosystems & pollution' and 'validation split training' : 0.9999983001190575
# Similarity between 'Field spectroscopy and portable spectroradiometers' and 'algorithm accuracy fold' : 0.9999982843865851
# Similarity between 'In-phase/Quadrature Component' and 'actions start risk' : 0.9999982816191465
# Similarity between 'Users in agriculture' and 'part test split' : 0.9999982760092846
# Similarity between 'Data quality standards' and 'test separately evaluate' : 0.9999982644270953
# Similarity between 'Cooperation levels' and 'algorithm accuracy fold' : 0.9999982624564819
# Similarity between 'Users in marine' and 'part test split' : 0.9999982584555501
# Similarity between 'Users in retail & geo-marketing' and 'rate intensive care' : 0.9999982398774985
# Similarity between 'Theory of mind' and 'countries collaborate share' : 0.9999982364258013
# Similarity between 'Theory of mind' and 'countries united kingdom' : 0.9999982364257929
# Similarity between 'Class stability' and 'class classification stringency' : 0.999998229880573
# Similarity between 'Time' and 'implement government agent' : 0.9999982255903429
# Similarity between 'GIS and T teaching and learning methods' and 'set countries fewer' : 0.9999982201439135
# Similarity between 'Monitor weather impact on ocean surface' and 'nave random forest' : 0.999998218414698
# Similarity between 'Monitor the built environment' and 'nave random forest' : 0.9999982167967866
# Similarity between 'The Carbon Cycle, Greenhouse Effect' and 'individuals considered ultimate' : 0.9999982140218335
# Similarity between 'Radiometric quantities: radiance, irradiance, flux, brightness, emittance, luminosity, etc.' and 'role disease interventions' : 0.9999982080804263
# Similarity between 'Users in meteo & climate' and 'part test split' : 0.9999981955396263
# Similarity between 'Users in fishing' and 'part test split' : 0.9999981813505036
# Similarity between 'Users in forestry' and 'part test split' : 0.9999981813505036
# Similarity between 'Users in construction' and 'part test split' : 0.9999981813505036
# Similarity between 'Users in leisure' and 'part test split' : 0.9999981813505036
# Similarity between 'Data cubes' and 'data driven agent' : 0.999998172383766
# Similarity between 'Data cubes' and 'data driven agent' : 0.999998172383766
# Similarity between 'Data mash ups' and 'data driven agent' : 0.999998172383766
# Similarity between 'Monitor health' and 'hospitalisation rate intensive' : 0.9999981658002683
# Similarity between 'EO for health surveillance' and 'forest algorithms trained' : 0.9999981646033226
# Similarity between 'Geometric object features' and 'importance features determine' : 0.9999981565536309
# Similarity between 'Users of consumer solutions' and 'part test split' : 0.9999981360994026
# Similarity between 'Reclassification and selection operations' and 'experiences social agents' : 0.9999981316289258
# Similarity between 'Users in health care' and 'part test split' : 0.9999981310218651
# Similarity between 'Users in smart cities' and 'part test split' : 0.99999806941732
# Similarity between 'Users in utilities & supplies' and 'part test split' : 0.9999980694173198
# Similarity between 'Users in travel & tourism' and 'part test split' : 0.9999980694173198
# ...
# Watershed segmentation: 30
# Spatial autocorrelation: 45
# Kernel analysis (convolution): 42
# Combined filtering: 36
# Edge detectors: 28
# High-pass filtering: 34
# Lee-Sigma: 21
# Low-pass filtering: 34
# Object-based image analysis (OBIA): 45
# Class modelling: 41
# Hierarchical representation: 38
# Per-parcel analysis: 42
# Spatial features: 45
# Distance and proximity features: 36
# Planar geometric features: 30
# Topological features: 37
# Physical-model based analysis: 44
# Feature space polyhedralization: 44
# Radiative transfer modelling: 41
# Scale space analysis: 42
# Difference of Gaussian (DoG): 40
# Scale invariant feature transformation (SIFT): 44
# Image data quality: 38
# Data quality standards: 38
# Accessibility: 31
# GEO QA4EO: 40
# ISO standards: 41
# OGC standards: 29
# Product quality: 37
# Accuracy assessment: 15
# Error matrix: 27
# Ground reference: 38
# Kappa statistics: 42
# Root mean square error (RMSE): 30
# User validation: 42
# Quality indicators: 37
# Cloud cover percentage: 34
# Remote sensing lifecycle: 38
# Spatial coverage: 45
# Temporal validity: 37
# Infrastructure: 18
# Data cubes: 76
# Array databases: 27
# Open data cube: 38
# Image archives: 30
# Content-based image retrieval: 46
# Web portals: 21
# Online processing: 34
# Data and information access service (DIAS): 27
# OGC interfaces and OGC web processing service: 10
# Image processing (value) chain: 21
# Organizational and Institutional Aspects: 10
# Organizational structures, procedures and management: 27
# Organizational models for GIS management: 9
# Managing GIS operations and infrastructure: 43
# User roles: 42
# Strategic planning: 40
# Coordinating GIS Participants and Users: 40
# Ongoing GIS revision: 42
# Organizational changes: 15
# GIS and T workforce themes: 42
# GIS and T positions and qualifications: 42
# GIS and T staff development and evaluation: 42
# GIS and T training and education: 40
# GIS and T curriculum and course design: 42
# GIS and T teaching and learning methods: 42
# Geospatial data sharing: 34
# Drivers and incentives for sharing geospatial data: 34
# Barriers to geospatial information sharing: 16
# Legal framework for geospatial data sharing: 32
# Legal instruments for sharing geospatial data: 32
# Spatial Data Infrastructures: 37
# Adoption and implementation of standards: 41
# Coordination and organizational structure: 18
# Funding an SDI: 43
# SDI performance measurement and assessment: 44
# Next-generation SDIs: 42
# SDI governance: 43
# Organizations in the GIS and T domain: 42
# GI organization at the European Commission: 16
# Federal and national government organizations: 44
# Sub-national and local governments: 40
# Pan-European and global associations and professional organizations: 42
# The geospatial industry: 10
# Physical principles: 36
# Basics of Optical Remote Sensing: 38
# EM radiation: 12
# Electromagnetic Waves and Photons: 42
# Solar constant, solar insolation, daily insolation: 40
# Earth's radiation (intensity, spectrum, etc.): 44
# Electromagnetic spectrum: 42
# Maxwell Equations and EM waves' propagation: 46
# Planck law for the black body. Wien's displacement law: 42
# Rayleigh-Jeans approximation. Wien's approximation: 40
# Stefan–Boltzmann law. Kirchoff law: 42
# Concepts of Spectral Emissivity and Brightness Temperature.: 27
# Solar radiation at the Top of the Atmosphere. Solar spectrum: 42
# Radiation - Matter interaction: 38
# Atomic spectroscopy: 41
# The Rayleigh roughness criterion: 21
# Bidirectional Reflectance Distribution Function (BRDF): 9
# Bidirectional Reflectance Factor (BRF): 10
# Molecular absorption spectra: 42
# Line shape and (natural, pressure, Doppler) broadening: 45
# Voigt's line profile: 45
# Concepts of Transmittance, Absorbance, Reflectance, Scattering.: 27
# Concepts of Spectral Emissivity: 27
# Complex dielectric constants and refractive indices: 36
# EM rad. penetration in the matter: Attenuation Length: 36
# Scattering from rough surface: Lambertian and specular surfaces.: 42
# Sensing of EM radiation.: 37
# Radiometric quantities: radiance, irradiance, flux, brightness, emittance, luminosity, etc.: 38
# Decay of the emittance with the square of distance from the source: 10
# Spectral Signatures of the matter: 21
# Spectral Signature of Vegetation, Water, Soil: 41
# Spectral Signature of Mineral and Rocks: 40
# Spectral Signature of Clouds: 30
# Composition of spectral signatures (Linear Mixing): 46
# Definition of active and passive remote sensing techniques: 38
# Optical properties of water: 22
# Fundamentals of Radiative Transfer: 30
# General equation of radiative transfer.: 34
# Retrieval of atmospheric parameters by inversion of multi-spectral radiances: 11
# Cross Section of Extinction (Absorption, Scattering) per Mass Unit: 21
# Absorption Coefficient: 42
# Source Function (Coefficient): 11
# Beer-Bouguer-Lambert law.: 42
# Schwarzshild equation and its solutions: 42
# Concepts of Optical path and Optical thickness.: 38
# Radiative transfer in presence of clouds: 38
# Line-by-line radiative transfer models: 44
# Basics of Optics and Modern Physics of Sensors: 22
# Reflection, Refraction and Dispersion of the light: 42
# Einstein’s theory of radiation: photons, photoelectric effect, absorption, emission; Stimulated emission: the laser: 42
# Photovoltaic and photoconductive detectors: MCT, InSb, bolometer, CCD devices: 7
# Interference and Diffraction.: 42
# Special relativity; Electromagnetic fields equations and propagations: 42
# Helmotz’s equations; Scattering from inhomogeneous media.: 40
# Foundations of geometrical optics, geometrical theory of optical imaging: 21
# Elements of the theory of interference and interferometers: 42
# Elements of the theory of diffraction and grating spectrometers: 42
# Basics of Atmospheric Physics: 16
# Structure and chemical-physical composition of Earth's atmosphere: 45
# Water vapour and Cloud formation: 45
# Radiative Equilibrium. Adiabatic lapse rate: 9
# The Carbon Cycle, Greenhouse Effect: 42
# Absorption and scattering of solar radiation in the Atmosphere: 42
# Mie Scattering in the Earth's Atmosphere: 40
# Rayleigh Scattering in the Earth's Atmosphere: 40
# Thermal infrared radiation transfer in the atmosphere: 44
# Light scattering by atmospheric particulates: 42
# Earth's (standard) Atmosphere Transmittance: 40
# Atmospheric (spectral) windows for EO: 42
# The Water Cycle: 45
# Basics of Thermodynamics: 41
# Temperature and heat: 45
# The constitutive equations of irreversible fluxes: 40
# Heat equation and special adiabatic systems, special adiabats of homogeneous systems: 45
# Thermodynamics diagram, atmosphere static: 40
# Kinetic theory of gases: 42
# Ideal gas laws: 40
# State function of ideal gases: 40
# State function of the condensed gas phase: 40
# Thermodynamic process: 42
# Budget equations: 40
# First law of thermodynamic: 29
# Second law of thermodynamics: 43
# Basics of Mechanics: 45
# Equation of the rocket and launch of a satellite: payload determination: 21
# Real orbits. Life time of a satellite, orbit’s decay.: 43
# Satellite orbits parametrization and choice: 9
# Basics of microwave remote sensing: 39
# Microwave portion of electromagnetic spectrum: 26
# Complex wave description: 21
# In-phase/Quadrature Component: 42
# Polarisation: 35
# Coherent: 43
# Phase: 40
# Doppler effect: 43
# Wave-particle dualism: 44
# Interaction of microwaves with matter: 42
# Diffraction: 42
# Scattering and emission: 42
# Radar cross-section: 42
# Radar equation: 43
# Sigma nought: 9
# Gamma nought: 9
# Beta nought (brightness): 20
# Dielectric Properties: 43
# Material constants: 36
# Attenuation lenght and penetration depth: 38
# Soil permittivity: 42
# Plant permittivity: 42
# Surface roughness: 42
# Vertical roughness component (RMS height): 22
# Horizontal roughness component (correlation length): 22
# Surface correlation function: 40
# Surface roughness slope: 42
# Single-scale & multi-scale roughness: 34
# Stokes Vector: 42
# Scattering matrix: 24
# Polarimetric decomposition techniques: 38
# Orientation polarisation of media: 40
# Polarimetric coherences: 44
# Polarisation ellipse / Jones vector formalism: 41
# Polarisation synthesis: 35
# Detecting microwaves: 18
# Radar antennas and antenna calibration: 42
# Antenna gain: 15
# Antenna pattern: 30
# Radargrammetric equation: 27
# Principles of Synthetic Aperture Radar Interferometry (InSAR): 43
# Differential Synthetic Aperture Radar Interferometry (DInSAR): 42
# Permanent Scatterer Interferometry (PSI): 22
# Along-Track Interferometry: 22
# Across-Track Interferometry: 22
# Small Baseline Subset: 26
# Synthetic Aperture Radar (SAR) tomography: 42
# Active-Passive microwave imaging: 36
# Coherent and active systems: 39
# Passive microwave imaging: 37
# Real Aperture Radar (RAR): 34
# Principles of Synthetic Aperture Radar (SAR): 43
# Synthetic Aperture Radar (SAR) geometric configuration: 42
# Azimuth direction: 42
# Range direction: 42
# Incidence Angle: 40
# Antenna footprint: 15
# Synthetic Aperture Radar (SAR) spatial resolution: 45
# Terrain reflectivity and geometric distortions: 27
# Local Incidence Angle: 40
# Speckle Formation: 31
# Platforms, sensors and digital imagery: 44
# Types of remote sensing sensors: 38
# History of remote sensing sensors: 37
# Passive vs. active sensors: 21
# Line detector arrays: 45
# Along track scanners: 3
# Area Arrays: 45
# Digital Frame Camera: 40
# Radiometers: 37
# Thermal Radiometers: 45
# Passive Microwave Radiometers: 38
# Hyperspectral Radiometers: 37
# Spectroradiometers: 41
# Atmospheric passive sounders: 10
# Imaging Radar: 42
# LiDAR (Light Detection and Ranging): 16
# Laser altimeter: 42
# Laser profiler: 42
# Radar altimeters: 42
# Ranging camera: 40
# Laser scanner: 42
# Spaceborne Laser Scanning: 45
# Airborne Laser Scanning: 27
# Mobile Laser Scanning: 35
# Underwater Laser Scanning: 35
# Bathymetric Laser Scanning: 35
# Sonic sensors: 11
# Seismic sensor: 31
# Radar Scatterometers: 42
# Differential Absorption Lidar: 46
# Doppler Wind LiDAR: 46
# Imaging vs. nonimaging sensors: 12
# Structured-light-projection camera: 42
# Speckle-pattern based sensor: 43
# Across track scanners: 3
# Multi-temporal pattern based sensor: 45
# Multi-spectral pattern based sensor: 45
# Ground penetrating RADAR (GPR): 42
# Optical spectrometers: 36
# Types of remote sensing platforms and systems: 34
# History of Remote Sensing Platforms: 38
# Unmanned Aerial Systems (UAS): 44
# Airborne platforms and systems: 39
# Mission planning: 40
# Spaceborne platforms and systems: 41
# Earth observation missions: 37
# Types of satellite orbits: 37
# Synthetic Aperture Radar (SAR) acquisition modes: 42
# Ground platforms and systems: 38
# Field spectroscopy and portable spectroradiometers: 37
# Terrestrial Laser Scanning: 35
# Remote sensing data and imagery: 38
# History of remote sensing data carriers: 38
# Digital image terminology: 44
# Picture element (pixel): 10
# Image as a matrix (digital number DN): 44
# Earth Observation Big Data: 38
# Data storage: 38
# Band interleaved by line (BIL): 45
# Band interleaved by pixel (BIP): 29
# Band sequential (BSQ): 36
# Properties of digital imagery: 42
# Spectral resolution: 45
# Spatial resolution: 45
# Radiometric resolution: 31
# Temporal resolution: 41
# Image description files: 29
# Data formats: 38
# Processing levels: 36
# Processing levels of optical data: 38
# Radiometrically corrected: 40
# Geometrically corrected: 40
# Synthetic Aperture Radar (SAR) data: 37
# Single Look Complex (SLC): 35
# Multi-looked Detected (MLD): 36
# Groud Range Detected (GRD): 11
# Analysis Ready Data (ARD): 38
# Databases of satellite and airborne sensors and missions: 22
# Spatial dependency: 45
# Spatial heterogeneity: 45
# Thematic and application domains: 26
# User community of EO services and applications: 46
# Users in managed living resources: 40
# Users in agriculture: 40
# Users in fishing: 40
# Users in forestry: 40
# Users in energy and mineral resources: 40
# Users in alternative energy: 40
# Users in oil & gas: 40
# Users in minerals & mining: 40
# Users in infrastructure & transport: 40
# Users in construction: 40
# Users in utilities & supplies: 40
# Users in communications & connectivity: 40
# Users in transport & logistics: 40
# Users in marine: 40
# Users in travel & tourism: 40
# Users in financial & digital services: 40
# Users in insurance & real estate: 40
# Users in retail & geo-marketing: 40
# Users in news & media: 40
# Users in ICT, knowledge and digital interfaces: 40
# Users in urban development: 40
# Users in smart cities: 40
# Users in local & regional planning: 40
# Users in defense & security: 40
# Users in defense, security & military: 40
# Users in emergency & social protection: 40
# Users in humanitarian operations: 40
# Users in environmental, climate & health: 40
# Users in environmental ecosystems & pollution: 40
# Users in health care: 40
# Users in meteo & climate: 40
# Users among citizens & society: 40
# Users of consumer solutions: 40
# Users in leisure: 40
# Users in education, training & research: 40
# EO for societal and environmental challenges: 40
# EO for climate change mitigation & adaptation: 40
# EO for sustainable urban development: 42
# EO for biodiversity & ecosystems: 40
# EO for digital agenda & new skills: 40
# EO for energy transition: 40
# EO for sustainable agriculture & food production: 40
# EO for infrastructure & transport: 42
# EO for health surveillance: 40
# EO for emergency, security & defense: 40
# EO for water sustainability: 41
# EO services and applications: 44
# Monitor the atmosphere and climate: 40
# Monitor the atmosphere: 40
# Monitor the climate: 40
# Forecast the weather: 40
# Monitor security & safety: 40
# Monitor critical assets: 41
# Monitor health: 40
# Food security monitoring: 40
# Monitor borders: 40
# Assess disasters & geohazards: 40
# Map and assess flooding: 44
# Detect and monitor wildfires: 40
# Assess damage from earthquakes: 40
# Forecast and assess landslides: 40
# Assess and monitor volcanic activities: 40
# Multi-hazard assessment: 40
# Monitor land: 44
# Monitor crops: 40
# Monitor the forest: 40
# Monitor bodies of water: 40
# Monitor snow and ice: 40
# Monitor land ecosystems: 42
# Monitor land use: 43
# Monitor topography: 40
# Extract information about subsurface geology: 44
# Monitor the built environment: 40
# Monitor urban areas: 40
# Monitor infrastructure: 44
# Monitor marine: 40
# Monitor the marine ecosystem: 40
# Monitor coastal areas: 40
# Monitor weather impact on ocean surface: 40
# Monitor fisheries: 40
# Detect and monitor ships: 40
# Monitor sea-ice and icebergs: 40
# Standard EO products: 42
# Processing-related and preparatory products: 20
# Band combinations: 29
# Ocean colour: 40
# EO parameters: 40
# Descriptive analytics products: 45
# Geometrically measured EO products: 42
# Point clouds: 42
# Digital elevation models: 11
# Elevation change maps: 42
# Vector fields: 37
# Feature trajectories: 45
# Semantic labelling products: 12
# Thematic classifications and feature detection: 44
# Land cover maps: 15
# Land use maps: 45
# Cloud mask: 42
# Detected features: 31
# Event maps and thematic change (evolution) maps: 42
# EO-derived attribute products: 42
# Predictive modelling products: 34
# Prescriptive modelling products and services: 10
# Aggregation and integration products: 26
# Textured 3D models: 42
# Semantic 3D models: 41
# EO visualisation products: 42
# Satellite maps: 45
# Layouted digital maps: 40
# Web visualisations in 2D and 3D: 16
# Analogue visualisation products: 44
# Time series map videos: 15
# Distribution services: 30
# Web-based GI: 27
# Web services: 28
# Fundamentals of web services: 31
# SOAP web services: 29
# REST web services: 29
# OGC web services: 21
# Resource Definition: 34
# Languages for the definition of non-spatial data and services: 36
# Definition of geospatial data: 34
# Ontologies development reuse and patterns: 45
# Resource Publishing: 37
# Metadata and standards: 37
# Manual and automated forms of publishing: 36
# Catalogue services: 34
# Publishing open data: 38
# Publishing via a semantic definition of data: 38
# Publishing linked open data: 38
# Resource Discovery: 34
# Syntactic discovery: 38
# Semantic discovery: 36
# Discovery over linked open data: 38
# Application development via Data Integration: 36
# Integrating data from OGC web services: 34
# Schema matching and ontology alignment: 42
# Data mash ups: 38
# Application development via Web services composition: 21
# Manual Web Services Composition: 30
# Semi automated and Full-automated WSC: 38
# Web Application development elements: 16
# Web Map APIs and Libraries: 31
# Web application Frameworks and Geoportal frameworks: 9
# Mathematical models of uncertainty: Probability and statistics: 45
